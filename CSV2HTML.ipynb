# %%
import pandas as pd

# %%
NFLX_csv="Resources/NFLX.csv"

# %%
NFLX_df = pd.read_csv(NFLX_csv)

# %%
NFLX_df.head
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-06-19  361.720001  364.739990  356.119995  363.519989  363.519989
# 1  2019-06-20  365.910004  370.119995  361.220001  365.209991  365.209991
# 2  2019-06-21  365.000000  371.450012  365.000000  369.209991  369.209991
# 3  2019-06-24  370.269989  375.000000  370.200012  371.040009  371.040009
# 4  2019-06-25  370.750000  371.000000  358.290009  360.299988  360.299988
# 5  2019-06-26  361.600006  366.790009  361.600006  362.200012  362.200012
# 6  2019-06-27  363.200012  370.850006  363.200012  370.019989  370.019989
# 7  2019-06-28  370.260010  371.540009  364.869995  367.320007  367.320007
# 8  2019-07-01  373.500000  376.660004  372.000000  374.600006  374.600006
# 9  2019-07-02  374.890015  376.000000  370.309998  375.429993  375.429993
#
#     Volume
# 0  5667200
# 1  5899500
# 2  7448400
# 3  4830200
# 4  5750400
# 5  3669700
# 6  4138600
# 7  4592700
# 8  4992600
# 9  3625000

# %%
NFLX_df = NFLX_df.to_html()
NFLX_df
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Date</th>\n      <th>Open</th>\n      <th>High</th>\n      <th>Low</th>\n      <th>Close</th>\n      <th>Adj Close</th>\n      <th>Volume</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>2019-06-19</td>\n      <td>361.720001</td>\n      <td>364.739990</td>\n      <td>356.119995</td>\n      <td>363.519989</td>\n      <td>363.519989</td>\n      <td>5667200</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>2019-06-20</td>\n      <td>365.910004</td>\n      <td>370.119995</td>\n      <td>361.220001</td>\n      <td>365.209991</td>\n      <td>365.209991</td>\n      <td>5899500</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2019-06-21</td>\n      <td>365.000000</td>\n      <td>371.450012</td>\n      <td>365.000000</td>\n      <td>369.209991</td>\n      <td>369.209991</td>\n      <td>7448400</td>\n    </tr>\n    <tr>\n      <th>3</th>\n   
# ...
